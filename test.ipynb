# %%
import pandas as pd
import os

# %%
df_list_misc = []


for root, dirs, files in os.walk('Match-Reports'):
    for file in files:
        if file.endswith('.pkl'):
            file_path = os.path.join(root, file)
            df = pd.read_pickle(file_path)

df
# Out:
#            date          home_team                away_team home_score  \
# 0    2021-08-13          Brentford                  Arsenal          2
# 1    2021-08-14  Manchester United             Leeds United          5
# 2    2021-08-14     Leicester City  Wolverhampton Wanderers          1
# 3    2021-08-14            Burnley   Brighton & Hove Albion          1
# 4    2021-08-14            Chelsea           Crystal Palace          3
# ..          ...                ...                      ...        ...
# 375  2022-05-22       Norwich City        Tottenham Hotspur          0
# 376  2022-05-22    Manchester City              Aston Villa          3
# 377  2022-05-22          Liverpool  Wolverhampton Wanderers          3
# 378  2022-05-22            Burnley         Newcastle United          1
# 379  2022-05-22            Chelsea                  Watford          2
#
#     away_score         referee
# 0            0  Michael Oliver
# 1            1    Paul Tierney
# ...
